# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.io as io
import scipy.signal as sig
import math as math
import random 
from scipy import integrate
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
plt.style.use('seaborn-colorblind')
plt.rcParams['image.cmap'] = 'RdBu'

# %%
# Demographics for each region
# Income

# %%
import matplotlib.pyplot as plt
import h5py

# %%
h5_file = '/Users/raymondarevalo/Documents/cogs108/COGS108-Gentrification/cogs108.h5'
with h5py.File(h5_file, 'r') as h5:
    # Data from 2012
    dset = h5['hp']
    #_ = plt.plot(dset[:][:])
    print([key for key in h5.keys()])
    plt.xlabel('years since 2007')
    plt.ylabel('average sales price, all homes')
    plt.title('')
    _ = plt.plot(dset[:][:])
# Out:
# ['crime_rate_2012', 'crime_rate_5y', 'hp']
